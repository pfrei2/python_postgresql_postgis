# %% [markdown]
# # Arbeitspaket (AP) 3: Management & Nutzung Räumliche Daten

# %% [markdown]
# ### Angaben Studierende(r) (fehlende Angaben ergänzen)

# %% [markdown]
# <table>
#   <tr>
#     <td>Vorname:</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Nachname:</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Immatrikulationsnummer:</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Modul:</td>
#     <td>Data Science</td>
#   </tr>
#   <tr>
#     <td>Prüfungsdatum / Raum / Zeit:</td>
#     <td>07.10.2024 / Raum: SF O3.54 / 8:00 – 11:45</td>
#   </tr>
#   <tr>
#     <td>Erlaubte Hilfsmittel:</td>
#     <td>w.MA.XX.DS.24HS (Data Science)<br>Open Book, Eigener Computer, Internet-Zugang</td>
#   </tr>
#   <tr>
#   <td>Nicht erlaubt:</td>
#   <td>Nicht erlaubt ist der Einsatz beliebiger Formen von generativer KI (z.B. Copilot, ChatGPT) <br> sowie beliebige Formen von Kommunikation oder Kollaboration mit anderen Menschen.</td>
# </tr>
# </table>

# %% [markdown]
# ## Bewertungskriterien
#
# ### <b style="color: gray;">(max. erreichbare Punkte: 48)</b>
#
# <table>
#   <thead>
#     <tr>
#       <th>Kategorie</th>
#       <th>Beschreibung</th>
#       <th>Punkteverteilung</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Code nicht lauffähig oder Ergebnisse nicht sinnvoll</td>
#       <td>Der Code enthält Fehler, die verhindern, dass er ausgeführt werden kann (z.B. Syntaxfehler) oder es werden Ergebnisse ausgegeben, welche nicht zur Fragestellung passen.</td>
#       <td>0 Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig, aber mit gravierenden Mängeln</td>
#       <td>Der Code läuft, aber die Ergebnisse sind aufgrund wesentlicher Fehler unvollständig (z.B. fehlende Joins, gravierende Fehler in SQL-Abfragen). Nur geringer Fortschritt erkennbar.</td>
#       <td>25% der max. erreichbaren Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig, aber mit mittleren Mängeln</td>
#       <td>Der Code läuft und liefert teilweise korrekte Ergebnisse, aber es gibt grössere Fehler (z.B. fehlende Spalten, unvollständige SQL-Abfragen). Die Ergebnisse sind nachvollziehbar, aber unvollständig oder ungenau.</td>
#       <td>50% der max. erreichbaren Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig, aber mit minimalen Mängeln</td>
#       <td>Der Code läuft und liefert ein weitgehend korrektes Ergebnis, aber kleinere Fehler (z.B. falsche oder fehlende Sortierung, Rundung von Werten falsch) beeinträchtigen die Vollständigkeit des Ergebnisses.</td>
#       <td>75% der max. erreichbaren Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig und korrekt</td>
#       <td>Der Code läuft einwandfrei und liefert das korrekte Ergebnis ohne Mängel.</td>
#       <td>100% der max. erreichbaren Punkte</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### <b>Python Libraries und Settings</b>

# %%
# Libraries
import os
import folium
import pandas as pd
import geopandas as gpd
from sqlalchemy import create_engine, text

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

print(os.getcwd())
# Out:
# /workspaces/python_postgresql_postgis

# %% [markdown]
# ## <b>Vorbereitung (Hinweis: dieser Teil wird <u>nicht</u> bewertet)</b>

# %% [markdown]
# #### <b>1.) Starten Sie eine GitHub Codespaces Instanz auf Basis Ihres Forks des folgenden GitHub Repositories:</b>
#
# ##### GitHub-Repository: https://github.com/mario-gellrich-zhaw/python_postgresql_postgis
#
# ##### <span style="color: red;"><b>WICHTIG!!! Verwenden Sie eine GitHub Codespaces Instanz mit ausreichend Arbeitsspeicher (4core, 16GB RAM).</b></span>
#
# <b>Hinweis:</b>
# - Im Unterricht wurden bereits sämtliche Installationen und Einstellungen inkl. der Registrierung des Datenbank Servers auf pgAdmin vorgenommen.
# - Falls Sie die Codespaces-Instanz neu erstellen müssen, folgen Sie bitte den detaillierten Erklärungen auf der README-Seite des GitHub Repositories.

# %% [markdown]
# #### <b>2.) Erstellen und Testen Sie die Datenbankverbindung mit der 'osm_switzerland' Datenbank.</b>

# %%
# Set up Database Connection
user = "pgadmin"
password = "geheim"
host = "localhost"
port = "5432"
database = "osm_switzerland"

# Erstellen der Connection URL
db_connection_url = "postgresql://" + user + ":" + password +\
                    "@" + host + ":" + port + "/" + database

# Erstellen SQLAlchemy Engine
engine = create_engine(db_connection_url)

# Test der Connection
with engine.connect() as connection:
    result = connection.execute(text('SELECT current_database()'))
    print(result.fetchone())

# Verbindung trennen
engine.dispose()
# Out:
# ('osm_switzerland',)

# %% [markdown]
# ## <b>Aufgaben (Dieser Teil wird bewertet!)</b>
# <b>Hinweise zu den folgenden Aufgabenstellungen:</b>
# <ul>
#   <li>In diesem Jupyter Notebook gibt es jeweils zwei Code-Zellen pro Aufgabe:</li>
#   <ol>
#     <li>Eine Codezelle mit Python-Code und einem SQL-Statement für die Datenbank-Abfrage.</li>
#     <li>Eine Codezelle mit Python-Code für die Kartendarstellung der Ergebnisse der jeweiligen SQL-Abfrage.</li>
#   </ol>
#   <li>In den Codezellen für die Datenbank-Abfrage muss jeweils das SQL-Statement ergänzt werden.</li>
#   <li>In den Codezellen für die Kartendarstellung muss nur dann der Python Code ergänzt werden, wenn in der Aufgabe danach gefragt wird.</li>
# </ul>
# <b style="color:red;">Beachten Sie, dass für die Punktevergabe auch die weiteren Anforderungen zu den Fragen unter 'Details zur Aufgabenstellung' herangezogen werden.</b>

# %% [markdown]
# #### <b>Aufgabe (1): Erstellen Sie eine Abfrage sämtlicher Autoreparatur-Werkstätten.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Daten in der Tabelle 'planet_osm_point'.
# - Stellen sie in der Ergebnistabelle die Spalten: osm_id, shop sowie die transformierte Geometrie als Spalte geom dar.
# - Tipp: Die Geometry wird mit Hilfe der Funktion st_transform() transformiert, z.B.: *st_transform(p.way, 4326) AS geom*.
# - Tipp: Autoreparatur-Werkstätten sind mit dem key:value Paar shop='car_repair' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 6)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            h.osm_id,
            h.shop,
            st_transform(h.way, 4326) AS geom
         FROM 
            public.planet_osm_point AS h
         WHERE
            h.shop = 'car_repair';"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#           osm_id        shop                      geom
# 0     7390840334  car_repair  POINT (8.84295 47.25249)
# 1    10720179451  car_repair  POINT (8.83955 47.29939)
# 2     1157271363  car_repair   POINT (8.91874 47.3296)
# 3    12163869427  car_repair  POINT (8.76669 47.51608)
# 4     4879747540  car_repair   POINT (8.7801 47.50343)
# ..           ...         ...                       ...
# 297   5837669722  car_repair   POINT (8.49517 47.4798)
# 298   5837669721  car_repair   POINT (8.49197 47.4802)
# 299   4067068634  car_repair   POINT (8.4632 47.48421)
# 300   3096308075  car_repair  POINT (8.60136 47.64363)
# 301  10811238450  car_repair   POINT (8.54339 47.5655)
#
# [302 rows x 3 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=10, 
               tiles='CartoDB positron')

# Map settings
folium.GeoJson(
    gdf,
    name='map'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_305ee63ba6466bcbb926de09ff902519 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_305ee63ba6466bcbb926de09ff902519&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_305ee63ba6466bcbb926de09ff902519 = L.map(
#                 &quot;map_305ee63ba6466bcbb926de09ff902519&quot;,
#                 {
#                     center: [47.39179473583919, 8.618542159602649],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b40d913d1f24ab5fe7cbf031725b84cd = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b40d913d1f24ab5fe7cbf031725b84cd.addTo(map_305ee63ba6466bcbb926de09ff902519);
#
#
#
#         function geo_json_47f1f521febc0d99b89a70111e6c14a7_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_47f1f521febc0d99b89a70111e6c14a7 = L.geoJson(null, {
#                 onEachFeature: geo_json_47f1f521febc0d99b89a70111e6c14a7_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_47f1f521febc0d99b89a70111e6c14a7_add (data) {
#             geo_json_47f1f521febc0d99b89a70111e6c14a7
#                 .addData(data);
#         }
#             geo_json_47f1f521febc0d99b89a70111e6c14a7_add({&quot;bbox&quot;: [8.375916299999998, 47.19164830012115, 8.9187427, 47.64363020002107], &quot;features&quot;: [{&quot;bbox&quot;: [8.8429547, 47.25249140010813, 8.8429547, 47.25249140010813], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.8429547, 47.25249140010813], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 7390840334, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8395537, 47.29939390009797, 8.8395537, 47.29939390009797], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.8395537, 47.29939390009797], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 10720179451, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.9187427, 47.3295990000914, 8.9187427, 47.3295990000914], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.9187427, 47.3295990000914], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 1157271363, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.7666868, 47.51607990005002, 8.7666868, 47.51607990005002], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.7666868, 47.51607990005002], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 12163869427, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.7800979, 47.50342720005288, 8.7800979, 47.50342720005288], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.7800979, 47.50342720005288], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 4879747540, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.777920499999999, 47.50197480005321, 8.777920499999999, 47.50197480005321], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.777920499999999, 47.50197480005321], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 4879747526, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.780787199999999, 47.50174030005326, 8.780787199999999, 47.50174030005326], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.780787199999999, 47.50174030005326], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;6&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 4879747537, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.7036809, 47.47941990005827, 8.7036809, 47.47941990005827], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.7036809, 47.47941990005827], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;7&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 4125136762, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.732690799999999, 47.4932998000551

# %% [markdown]
# #### <b>Aufgabe (2) Erstellen Sie eine Abfrage aller Biergärten.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Daten in den Tabellen 'planet_osm_point'.
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, amenity, name und die transformierte Geometrie als Spalte geom dar.
# - Tipp: Biergärten sind mit dem key:value Paar amenity='biergarten' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 6)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            h.osm_id,
            h.amenity,
            h.name,
            st_transform(h.way, 4326) AS geom
         FROM
            public.planet_osm_point AS h
         WHERE
            h.amenity = 'biergarten';"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf.head()
# Out:
#        osm_id     amenity            name                      geom
# 0  2679062372  biergarten  Gamschtä Träff  POINT (8.76787 47.23535)
# 1   768907979  biergarten    Engel Lounge  POINT (8.67547 47.23005)
# 2  2518707388  biergarten  zum Adlerhorst  POINT (8.68977 47.38973)

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=8, 
               tiles='CartoDB positron')

# Map settings
folium.GeoJson(
    gdf,
    name='map'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_495993f82987363f157e701d6551e797 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_495993f82987363f157e701d6551e797&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_495993f82987363f157e701d6551e797 = L.map(
#                 &quot;map_495993f82987363f157e701d6551e797&quot;,
#                 {
#                     center: [47.28504446676764, 8.711035866666666],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e5044ffbdaec8c70481ac649957a6b2 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0e5044ffbdaec8c70481ac649957a6b2.addTo(map_495993f82987363f157e701d6551e797);
#
#
#
#         function geo_json_92a9c96e9cb900b639ef701857ef515b_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_92a9c96e9cb900b639ef701857ef515b = L.geoJson(null, {
#                 onEachFeature: geo_json_92a9c96e9cb900b639ef701857ef515b_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_92a9c96e9cb900b639ef701857ef515b_add (data) {
#             geo_json_92a9c96e9cb900b639ef701857ef515b
#                 .addData(data);
#         }
#             geo_json_92a9c96e9cb900b639ef701857ef515b_add({&quot;bbox&quot;: [8.6754669, 47.23005180011294, 8.767871899999998, 47.38973230007818], &quot;features&quot;: [{&quot;bbox&quot;: [8.767871899999998, 47.235349300111814, 8.767871899999998, 47.235349300111814], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.767871899999998, 47.235349300111814], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;amenity&quot;: &quot;biergarten&quot;, &quot;name&quot;: &quot;Gamscht\u00e4 Tr\u00e4ff&quot;, &quot;osm_id&quot;: 2679062372}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.6754669, 47.23005180011294, 8.6754669, 47.23005180011294], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.6754669, 47.23005180011294], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;amenity&quot;: &quot;biergarten&quot;, &quot;name&quot;: &quot;Engel Lounge&quot;, &quot;osm_id&quot;: 768907979}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.6897688, 47.38973230007818, 8.6897688, 47.38973230007818], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.6897688, 47.38973230007818], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;amenity&quot;: &quot;biergarten&quot;, &quot;name&quot;: &quot;zum Adlerhorst&quot;, &quot;osm_id&quot;: 2518707388}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_92a9c96e9cb900b639ef701857ef515b.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_92a9c96e9cb900b639ef701857ef515b.addTo(map_495993f82987363f157e701d6551e797);
#
#
#             var layer_control_cc7c3edd64a0823ba559b49c986a7ed8_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_0e5044ffbdaec8c70481ac649957a6b2,
#                 },
#                 overlays :  {
#                     &quot;map&quot; : geo_json_92a9c96e9cb900b639ef701857ef515b,
#                 },
#             };
#             let layer_control_cc7c3edd64a0823ba559b49c986a7ed8 = L.control.layers(
#                 layer_control_cc7c3edd64a0823ba559b49c986a7ed8_layers.base_layers,
#                 layer_control_cc7c3edd64a0823ba559b49c986a7ed8_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_495993f82987363f157e701d6551e797);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### <b>Aufgabe (3): Erstellen Sie eine Abfrage aller Gebäude in der Stadthausstrasse in Winterthur, welche vollständige Adressangaben besitzen.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Daten in der Tabelle 'planet_osm_polygon'.
# - Vollständige Adressangabe bedeutet: Strassenname, Haunummer, PLZ, Gemeindename sind vorhanden.
# - Stellen Sie in der Ergebnistabelle sämtliche Adressangaben sowie die transformierte Geometrie als Spalte geom dar.
# - Verwenden Sie für die Darstellung als Hintergrundkarte ein Satellitenbild (ESRIWorldImagery) als maptile.
# - Tipp: Gebäude sind in der Spalte 'building' klassifiziert. Mit *WHERE building IS NOT NULL* können Sie Gebäude filtern.
#
# <b style="color: gray;">(max. erreichbare Punkte: 6)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            p.osm_id,
            p."addr:street",
            p."addr:housenumber",
            p."addr:city",
            p."addr:postcode",
            st_transform(p.way, 4326) AS geom
        FROM
            planet_osm_polygon AS p
        WHERE
            p.building IS NOT NULL
            AND p."addr:street" = 'Stadthausstrasse'
            AND p."addr:housenumber" IS NOT NULL
            AND p."addr:postcode" IS NOT NULL
            AND p."addr:city" = 'Winterthur';"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#        osm_id       addr:street addr:housenumber   addr:city addr:postcode  \
# 0    94283231  Stadthausstrasse              145  Winterthur          8400
# 1    94283304  Stadthausstrasse              143  Winterthur          8400
# 2    24804763  Stadthausstrasse               22  Winterthur          8400
# 3    26992511  Stadthausstrasse               24  Winterthur          8400
# 4    75027485  Stadthausstrasse               31  Winterthur          8400
# ..        ...               ...              ...         ...           ...
# 56  232998352  Stadthausstrasse              133  Winterthur          8400
# 57  188158693  Stadthausstrasse              119  Winterthur          8400
# 58  188158697  Stadthausstrasse              117  Winterthur          8400
# 59  188158696  Stadthausstrasse              115  Winterthur          8400
# 60  188158695  Stadthausstrasse              113  Winterthur          8400
#
#                                                  geom
# 0   POLYGON ((8.72414 47.4995, 8.72417 47.49939, 8...
# 1   POLYGON ((8.72427 47.49952, 8.72431 47.4994, 8...
# 2   POLYGON ((8.72448 47.49982, 8.72453 47.4997, 8...
# 3   POLYGON ((8.72405 47.49972, 8.72407 47.49967, ...
# 4   POLYGON ((8.73162 47.50041, 8.73165 47.50029, ...
# ..                                                ...
# 56  POLYGON ((8.72543 47.4995, 8.72546 47.49949, 8...
# 57  POLYGON ((8.72634 47.49979, 8.7264 47.49961, 8...
# 58  POLYGON ((8.72682 47.49986, 8.72687 47.49972, ...
# 59  POLYGON ((8.72694 47.49988, 8.72696 47.49974, ...
# 60  POLYGON ((8.72702 47.4999, 8.72706 47.49975, 8...
#
# [61 rows x 6 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=17, 
               tiles='CartoDB positron')

# Map settings
folium.Choropleth(
    geo_data=gdf,
    name='map',
    fill_color='greenyellow'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e063a68aa35d7c7b470281e50a94148 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e063a68aa35d7c7b470281e50a94148&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e063a68aa35d7c7b470281e50a94148 = L.map(
#                 &quot;map_1e063a68aa35d7c7b470281e50a94148&quot;,
#                 {
#                     center: [47.500044957105665, 8.727995077567487],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 17,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1032b4e9c270dcf3a5d8dc032fd8c94 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c1032b4e9c270dcf3a5d8dc032fd8c94.addTo(map_1e063a68aa35d7c7b470281e50a94148);
#
#
#             var choropleth_8e5e166c75addbc8908e7e25704fe736 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_30781762cfca3b9919639cae9d95d14d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;greenyellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_30781762cfca3b9919639cae9d95d14d_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_30781762cfca3b9919639cae9d95d14d = L.geoJson(null, {
#                 onEachFeature: geo_json_30781762cfca3b9919639cae9d95d14d_onEachFeature,
#
#                 style: geo_json_30781762cfca3b9919639cae9d95d14d_styler,
#             ...{
# }
#         });
#
#         function geo_json_30781762cfca3b9919639cae9d95d14d_add (data) {
#             geo_json_30781762cfca3b9919639cae9d95d14d
#                 .addData(data);
#         }
#             geo_json_30781762cfca3b9919639cae9d95d14d_add({&quot;bbox&quot;: [8.724050699999998, 47.49938870005378, 8.733014099999998, 47.50121620005338], &quot;features&quot;: [{&quot;bbox&quot;: [8.724137800000001, 47.49938870005378, 8.7243132, 47.49952200005375], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.724137800000001, 47.49950230005376], [8.7241741, 47.49939400005379], [8.7241883, 47.49939580005378], [8.724243299999998, 47.4994027000538], [8.7242472, 47.49938870005378], [8.7243132, 47.4993972000538], [8.7242736, 47.49952200005375], [8.724137800000001, 47.49950230005376]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Winterthur&quot;, &quot;addr:housenumber&quot;: &quot;145&quot;, &quot;addr:postcode&quot;: &quot;8400&quot;, &quot;addr:street&quot;: &quot;Stadthausstrasse&quot;, &quot;osm_id&quot;: 94283231}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.7242736, 47.4993972000538, 8.7244851, 47.49954730005374], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.7242736, 47.49952200005375], [8.7243132, 47.4993972000538], [8.7244851, 47.4994213000538], [8.724445, 47.49954730005374], [8.7242736, 47.49952200005375]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Winterthur&quot;, &quot;addr:housenumber&quot;: &quot;143&quot;, &quot;addr:postcode&quot;: &quot;8400&quot;, &quot;addr:street&quot;: &quot;Stadthausstrasse&quot;, &quot;osm_id&quot;: 94283304}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.7244848, 47.49969960005372, 8.724800499999999, 47.49986290005368], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.7244848, 47.499820100053704], [8.7245257, 47.49969960005372], [8.7245671, 47.49970600005373], [8.724800499999999, 47.49974220005373], [8.7247595, 47.49986290005368], [8.7246622, 47.49984780005368], [8.7246579, 47.499860400053684], [8.7245751, 47.49984750005368], [8.7245794, 47.49983470005368], [8.7244848, 47.499820100053704]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Winterthur&quot;, &quot;addr:housenumber&quot;: &quot;22&quot;, &quot;addr:postcode&quot;: &quot;8400&quot;, &quot;addr:street&quot;: &quot;Stadthausstrasse&quot;, &quot;osm_id&quot;: 24804763}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.724050699999998, 47.499634400053715, 8.724434799999997, 47.49988930005369], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.724050699999998, 47.499719900053705], [8.7240686, 47.499666200053724], [8.724081999999997

# %% [markdown]
# #### <b>Aufgabe (4): Erstellen Sie eine Abfrage aller Strassen welche als 'motorway' klassifiziert sind.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Informationen in der Tabelle 'planet_osm_roads'.
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, highway und die transformierte Geometrie als Spalte geom dar.
# - Tipp: Motorways sind mit dem key:value Paar highway='motorway' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 6)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            pr.osm_id,
            pr.highway,
            st_transform(pr.way, 4326) AS geom
         FROM
            planet_osm_roads AS pr
         WHERE
            pr.highway = 'motorway';"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#           osm_id   highway                                               geom
# 0      546365250  motorway     LINESTRING (8.83096 47.26077, 8.8309 47.26063)
# 1      546365251  motorway    LINESTRING (8.83104 47.26094, 8.83096 47.26077)
# 2       40528299  motorway    LINESTRING (8.83122 47.26097, 8.83134 47.26125)
# 3       40528306  motorway    LINESTRING (8.83116 47.26122, 8.83104 47.26094)
# 4      546365253  motorway  LINESTRING (8.8314 47.2618, 8.83129 47.26153, ...
# ...          ...       ...                                                ...
# 1133  1316916594  motorway  LINESTRING (8.83321 47.55294, 8.83281 47.5528,...
# 1134    41257941  motorway  LINESTRING (8.83225 47.55248, 8.8328 47.55268,...
# 1135   186446584  motorway  LINESTRING (8.83807 47.55406, 8.83729 47.55394...
# 1136  1316916597  motorway  LINESTRING (8.83703 47.55378, 8.83738 47.55384...
# 1137  1316916596  motorway  LINESTRING (8.83921 47.5542, 8.8389 47.55417, ...
#
# [1138 rows x 3 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=10, 
               tiles='CartoDB positron')

# Map settings
folium.Choropleth(
    geo_data=gdf,
    name='map',
    line_weight=3,
    line_color='red'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bac282ea7a03baea9714033e694abe24 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bac282ea7a03baea9714033e694abe24&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bac282ea7a03baea9714033e694abe24 = L.map(
#                 &quot;map_bac282ea7a03baea9714033e694abe24&quot;,
#                 {
#                     center: [47.39059021538855, 8.58229609138885],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_879259ae1653b8cd9310c48e71376f5a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_879259ae1653b8cd9310c48e71376f5a.addTo(map_bac282ea7a03baea9714033e694abe24);
#
#
#             var choropleth_d5b18365a8c0b7d268bcb9b956a962de = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_52fcfca5d5aa2c7d79fd339727205980_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_52fcfca5d5aa2c7d79fd339727205980_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_52fcfca5d5aa2c7d79fd339727205980 = L.geoJson(null, {
#                 onEachFeature: geo_json_52fcfca5d5aa2c7d79fd339727205980_onEachFeature,
#
#                 style: geo_json_52fcfca5d5aa2c7d79fd339727205980_styler,
#             ...{
# }
#         });
#
#         function geo_json_52fcfca5d5aa2c7d79fd339727205980_add (data) {
#             geo_json_52fcfca5d5aa2c7d79fd339727205980
#                 .addData(data);
#         }
#             geo_json_52fcfca5d5aa2c7d79fd339727205980_add({&quot;bbox&quot;: [8.3632475, 47.19620480012019, 8.9032688, 47.56752360003842], &quot;features&quot;: [{&quot;bbox&quot;: [8.8308994, 47.26063240010636, 8.830962599999998, 47.260768900106335], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.830962599999998, 47.260768900106335], [8.8308994, 47.26063240010636]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 546365250}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.830962599999998, 47.260768900106335, 8.8310407, 47.260935100106295], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.8310407, 47.260935100106295], [8.830962599999998, 47.260768900106335]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 546365251}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8312169, 47.260969100106294, 8.831339299999998, 47.26124960010623], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.8312169, 47.260969100106294], [8.831339299999998, 47.26124960010623]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 40528299}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8310407, 47.260935100106295, 8.8311646, 47.26121720010624], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.8311646, 47.26121720010624], [8.8310407, 47.260935100106295]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 40528306}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8311646, 47.26121720010624, 8.8313998, 47.26180450010611], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.8313998, 47.26180450010611], [8.8312908, 47.261525300106165], [8.8311646, 47.26121720010624]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 546365253}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8321748, 47.26389860010566, 8.832219099999998, 47.26411770010561], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.8321748, 47.26389860010566], [8.832219099999998, 47.26411770010561]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 546365255}, &quot;type

# %% [markdown]
# #### <b>Aufgabe (5): Erstellen Sie eine Abfrage aller Flüsse. Generieren Sie zusätzlich Buffer um die Flüsse mit einer Breite von 2000m.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Informationen in der Tabelle 'planet_osm_line'.
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, waterway sowie die transformierte Geometrie als Spalte geom dar.
# - Tipp: Flüsse sind mit dem key:value Paar waterway='river' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
# - Tipp: Per Default wird für jedes Fluss-Segment ein separater Buffer erstellt. Es ist nicht notwendig daraus einen einzelnen Buffer zu generieren.
#
# <b style="color: gray;">(max. erreichbare Punkte: 8)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            p.osm_id,
            p.waterway,
            ST_TRANSFORM(ST_Buffer(p.way::geometry, 3857), 2000) AS geom
         FROM
            planet_osm_line AS p
         WHERE
            p.waterway = 'river';"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#          osm_id waterway                                               geom
# 0      33606198    river  POLYGON ((5252493.655 8113523.219, 5252329.389...
# 1      33605947    river  POLYGON ((5248316.628 8120354.272, 5248294.017...
# 2     315137969    river  POLYGON ((5249214.102 8122785.933, 5249173.634...
# 3    1284695711    river  POLYGON ((5248466.99 8120045.278, 5248439.638 ...
# 4     668843910    river  POLYGON ((5249067.7 8117583.006, 5248910.369 8...
# ..          ...      ...                                                ...
# 230   948626536    river  POLYGON ((5222991.072 8095890.378, 5223010.666...
# 231    30072980    river  POLYGON ((5214717.294 8083581.259, 5214694.073...
# 232   288785572    river  POLYGON ((5185073.749 8122662.733, 5184673.681...
# 233    12373075    river  POLYGON ((5200831.518 8115439.572, 5200727.722...
# 234   833353743    river  POLYGON ((5208249.818 8130421.473, 5208001.529...
#
# [235 rows x 3 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=10, 
               tiles='CartoDB positron')

# Map settings
folium.Choropleth(
    geo_data=gdf,
    name='map',
    fill_color='greenyellow'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1122da5b17477897804d30994e7de17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1122da5b17477897804d30994e7de17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b1122da5b17477897804d30994e7de17 = L.map(
#                 &quot;map_b1122da5b17477897804d30994e7de17&quot;,
#                 {
#                     center: [8116671.461438958, 5227334.244262332],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e1b34b52adc6a15522f259c350f2998 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7e1b34b52adc6a15522f259c350f2998.addTo(map_b1122da5b17477897804d30994e7de17);
#
#
#             var choropleth_3e74a95da49a4e63364de58c995c5e14 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_82dbdf6effba631ea731521b6ae093fb_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;greenyellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_82dbdf6effba631ea731521b6ae093fb_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_82dbdf6effba631ea731521b6ae093fb = L.geoJson(null, {
#                 onEachFeature: geo_json_82dbdf6effba631ea731521b6ae093fb_onEachFeature,
#
#                 style: geo_json_82dbdf6effba631ea731521b6ae093fb_styler,
#             ...{
# }
#         });
#
#         function geo_json_82dbdf6effba631ea731521b6ae093fb_add (data) {
#             geo_json_82dbdf6effba631ea731521b6ae093fb
#                 .addData(data);
#         }
#             geo_json_82dbdf6effba631ea731521b6ae093fb_add({&quot;bbox&quot;: [8.112193447361781, 47.1433115492887, 8.994854377560447, 47.7188763893365], &quot;features&quot;: [{&quot;bbox&quot;: [8.799882543674032, 47.213245906113116, 8.889455947339522, 47.265604959099214], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.800454609219054, 47.241769825378015], [8.800724780325298, 47.24311293851063], [8.800751480325285, 47.24321253059235], [8.802715394553822, 47.24781355361377], [8.802770094553829, 47.24790543832636], [8.804723263944204, 47.25065696340668], [8.804796363944224, 47.25074484421918], [8.807690195295674, 47.25368346353952], [8.811200176994111, 47.25629437406861], [8.811284076994115, 47.25634805672065], [8.817731246046204, 47.25960385262838], [8.817824646046194, 47.25964043855491], [8.818938649968164, 47.25997185121963], [8.821052683461708, 47.261098645916974], [8.821314983461706, 47.26122000138106], [8.823475836347232, 47.26214248560698], [8.823829336347256, 47.26228133223174], [8.826889033595751, 47.26334915151113], [8.827158933595753, 47.26343211794309], [8.830918776725499, 47.26441341153268], [8.8311951767255, 47.26447328619714], [8.837238322698598, 47.26538826016409], [8.837508622698616, 47.26541224959829], [8.840916878379248, 47.26559926162872], [8.841184878379265, 47.265604959099214], [8.846556568324464, 47.265435838474936], [8.846829468324465, 47.265412748652295], [8.851892861430178, 47.2647210708748], [8.852168261430188, 47.26466869327674], [8.85221999312814, 47.26465670456257], [8.85223209165079, 47.26465816119554], [8.859022827911126, 47.26456248187335], [8.865655575831374, 47.26356959896712], [8.871875442628651, 47.26171761963341], [8.877443402310089, 47.25907762908348], [8.882145481307667, 47.25575097180636], [8.885800981362515, 47.251865373530094], [8.888269423657471, 47.24757005042949], [8.889455947339522, 47.243029990845926], [8.889314954968937, 47.238419626831906], [8.887851864803473, 47.23391613689877], [8.885122902577647, 47.22969263641496], [8.881232940779428, 47.225911517454406], [8.876331468459181, 47.222718195171566], [8.870606846449373, 47.22023550300327], [8.867195675489763, 47.219331717851986], [8.865681630746538, 47.21880560545032], [8.865063630746539, 47.21860902643947], [8.863852450365801, 47.218242785237884], [8.8634926503658, 47.218139543029096], [8.859029426115676, 47.2170959192912], [8.858666726115672, 47.21702949082615], [8.855565082820513, 47.21656385647344], [8.855017982820529, 47.21649942830009], [8.853823986735282, 47.21637334447135], [8.853299974831573, 47.216324349855284], [8.85093299580175, 47.2154036772777], [8.8444935840413, 47.213936119811024], [8.841148265647032, 47.2136451217

# %% [markdown]
# #### <b>Aufgabe (6): Erstellen Sie eine Abfrage der Bäckerei-Geschäfte in Zürich und Winterthur.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Daten in den Tabellen 'planet_osm_point' (Backereien).
# - Verwenden Sie die Städtenamen aus den Adressangaben für die Abfrage der Bäckerei-Standorte (Zürich, Winterthur).
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, shop, name, "addr:city" sowie die transformierte Geometrie als geom dar.
# - Wählen Sie eine Satelliten Karte von ESRI als Hintergrundkarte (maptile).
# - Sortieren Sie die Bäckerei-Geschäfte aufsteigend nach osm_id.
# - Tipp: Bäckerei-Geschäfte sind mit dem key:value Paar shop='bakery' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 8)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            p.osm_id,
            p.shop,
            p.name,
            p."addr:city",
            st_transform(p.way, 4326) AS geom
         FROM
            planet_osm_point AS p
         WHERE
            p."addr:city" IN ('Winterthur', 'Zürich')
            AND p.shop = 'bakery'
        ORDER BY
            p.osm_id ASC;"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#           osm_id    shop                  name addr:city  \
# 0      252457457  bakery  Steiner Flughafebeck    Zürich
# 1      266630770  bakery           Brezelkönig    Zürich
# 2      267879346  bakery       Walter Buchmann    Zürich
# 3      268602152  bakery               Moser's    Zürich
# 4      270794699  bakery            John Baker    Zürich
# ..           ...     ...                   ...       ...
# 102  10884168277  bakery              Juliette    Zürich
# 103  10946043353  bakery         Babu's Bakery    Zürich
# 104  10955852823  bakery          Täglich Brot    Zürich
# 105  11951988149  bakery                Wagner    Zürich
# 106  12368630564  bakery                 Tsugi    Zürich
#
#                          geom
# 0    POINT (8.49779 47.40311)
# 1    POINT (8.48875 47.39147)
# 2     POINT (8.5191 47.36258)
# 3     POINT (8.54945 47.3632)
# 4    POINT (8.56645 47.36493)
# ..                        ...
# 102   POINT (8.5328 47.36658)
# 103  POINT (8.51568 47.37473)
# 104  POINT (8.50705 47.36079)
# 105   POINT (8.51763 47.3698)
# 106   POINT (8.53092 47.3933)
#
# [107 rows x 5 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=12, 
               tiles='CartoDB positron')

# Map settings
folium.GeoJson(
    gdf,
    name='map',
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ab9e42da7b86cd44e5b2b706e8d129b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ab9e42da7b86cd44e5b2b706e8d129b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ab9e42da7b86cd44e5b2b706e8d129b = L.map(
#                 &quot;map_4ab9e42da7b86cd44e5b2b706e8d129b&quot;,
#                 {
#                     center: [47.39487878605834, 8.555985045794392],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e795e293d92ef8f4f7c596c3a1cd71e6 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e795e293d92ef8f4f7c596c3a1cd71e6.addTo(map_4ab9e42da7b86cd44e5b2b706e8d129b);
#
#
#
#         function geo_json_de666ac6d50018e476264cdea3752fb1_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_de666ac6d50018e476264cdea3752fb1 = L.geoJson(null, {
#                 onEachFeature: geo_json_de666ac6d50018e476264cdea3752fb1_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_de666ac6d50018e476264cdea3752fb1_add (data) {
#             geo_json_de666ac6d50018e476264cdea3752fb1
#                 .addData(data);
#         }
#             geo_json_de666ac6d50018e476264cdea3752fb1_add({&quot;bbox&quot;: [8.481048199999998, 47.33904520008934, 8.7625839, 47.51028540005134], &quot;features&quot;: [{&quot;bbox&quot;: [8.497792, 47.40310610007525, 8.497792, 47.40310610007525], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.497792, 47.40310610007525], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Steiner Flughafebeck&quot;, &quot;osm_id&quot;: 252457457, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.4887528, 47.3914676000778, 8.4887528, 47.3914676000778], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.4887528, 47.3914676000778], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Brezelk\u00f6nig&quot;, &quot;osm_id&quot;: 266630770, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5191037, 47.36258390008416, 8.5191037, 47.36258390008416], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5191037, 47.36258390008416], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Walter Buchmann&quot;, &quot;osm_id&quot;: 267879346, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5494522, 47.36320120008403, 8.5494522, 47.36320120008403], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5494522, 47.36320120008403], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Moser\u0027s&quot;, &quot;osm_id&quot;: 268602152, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5664519, 47.36492500008365, 8.5664519, 47.36492500008365], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5664519, 47.36492500008365], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;John Baker&quot;, &quot;osm_id&quot;: 270794699, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5540543, 47.369558800082636, 8.5540543, 47.369558800082636], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5540543, 47.369558800082636], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Caf\u00e9 Berner&quot;, &quot;osm_id&quot;: 270799257, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.7313948, 47.49943290005378, 8.7313948, 47.49943290005378], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.7313948, 47.49943290005378], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;6&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Winterthur&quot;, &quo

# %% [markdown]
# #### <b>Aufgabe (7): Erstellen Sie eine Abfrage sämtlicher Coiffeur-Geschäfte in einem Radius von 500m um den Hauptbahnhof in Zürich.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die Daten in der Tabelle 'planet_osm_point'.
# - Berechnen Sie in der Abfrage die Distanz jedes Coiffeur-Geschäfts zum Hauptbahnhof in Metern als Spalte 'distance_meters'.
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, shop, name, distance_meters, sowie die transformierte Geometrie als geom dar.
# - Wählen Sie eine Satelliten Karte von ESRI als Hintergrundkarte (maptile).
# - Integrieren Sie in die Kartendarstellung den Namen (Spalte 'name') der Coiffeur-Geschäfte als Popup.
# - Tipp: Coiffeur-Geschäfte sind mit dem key:value Paar shop='hairdresser' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 8)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            p.osm_id,
            p.shop,
            p.name,
            ST_Distance(
                ST_Transform(p.way, 4326)::geography,
                -- Central station coordinates BHZ
                ST_SetSRID(ST_MakePoint(8.53936, 47.3781), 4326)::geography
            ) AS distance_meters,
            ST_Transform(p.way, 4326) AS geom
         FROM
            planet_osm_point AS p
         WHERE
            p.shop = 'hairdresser'
            AND ST_DWithin(
                ST_Transform(p.way, 4326)::geography,
                -- Central station coordinates
                ST_SetSRID(ST_MakePoint(8.53936, 47.3781), 4326)::geography,
                500);"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf.head()
# Out:
#         osm_id         shop           name  distance_meters  \
# 0  10967922628  hairdresser   Haar Galerie       344.902735
# 1    693318573  hairdresser          Gidor       329.529927
# 2   3646016593  hairdresser  Hairstudio 21       238.984265
# 3   4911713622  hairdresser     The Barber       360.260296
# 4   4869996370  hairdresser          Saleh       464.039122
#
#                        geom
# 0  POINT (8.54043 47.37508)
# 1  POINT (8.53999 47.37517)
# 2  POINT (8.53826 47.37608)
# 3   POINT (8.5366 47.37546)
# 4  POINT (8.53646 47.37442)

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=16, 
               tiles='CartoDB positron')

# Map settings
folium.GeoJson(
    gdf,
    name='map'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5230e50f41549e07cb36ead60b17c5e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5230e50f41549e07cb36ead60b17c5e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5230e50f41549e07cb36ead60b17c5e5 = L.map(
#                 &quot;map_5230e50f41549e07cb36ead60b17c5e5&quot;,
#                 {
#                     center: [47.37697799452545, 8.540641408333332],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07877b73f6069a20f5a7d90da858a6e3 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_07877b73f6069a20f5a7d90da858a6e3.addTo(map_5230e50f41549e07cb36ead60b17c5e5);
#
#
#
#         function geo_json_607dcbdd4c909d8904f983f0b85b98f4_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_607dcbdd4c909d8904f983f0b85b98f4 = L.geoJson(null, {
#                 onEachFeature: geo_json_607dcbdd4c909d8904f983f0b85b98f4_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_607dcbdd4c909d8904f983f0b85b98f4_add (data) {
#             geo_json_607dcbdd4c909d8904f983f0b85b98f4
#                 .addData(data);
#         }
#             geo_json_607dcbdd4c909d8904f983f0b85b98f4_add({&quot;bbox&quot;: [8.535649, 47.373807500081696, 8.5454687, 47.3806169000802], &quot;features&quot;: [{&quot;bbox&quot;: [8.5404331, 47.3750846000814, 8.5404331, 47.3750846000814], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5404331, 47.3750846000814], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 344.90273493, &quot;name&quot;: &quot;Haar Galerie&quot;, &quot;osm_id&quot;: 10967922628, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5399862, 47.3751667000814, 8.5399862, 47.3751667000814], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5399862, 47.3751667000814], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 329.52992738, &quot;name&quot;: &quot;Gidor&quot;, &quot;osm_id&quot;: 693318573, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.538264299999998, 47.3760834000812, 8.538264299999998, 47.3760834000812], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.538264299999998, 47.3760834000812], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 238.98426519, &quot;name&quot;: &quot;Hairstudio 21&quot;, &quot;osm_id&quot;: 3646016593, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5365986, 47.37545770008131, 8.5365986, 47.37545770008131], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5365986, 47.37545770008131], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 360.2602957, &quot;name&quot;: &quot;The Barber&quot;, &quot;osm_id&quot;: 4911713622, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.536456899999997, 47.37442140008157, 8.536456899999997, 47.37442140008157], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.536456899999997, 47.37442140008157], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 464.03912186, &quot;name&quot;: &quot;Saleh&quot;, &quot;osm_id&quot;: 4869996370, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.537131899999999, 47.37404510008163, 8.537131899999999, 47.37404510008163], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.537131899999999, 47.37404510008163], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 481.19580059, &quot;name&quot;: &quot;Coiffina&quot;, &quot;osm_id&quot;: 4841796186, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.540474, 47.373807500081696, 8.540474, 47.373807500081696], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.540474, 47.373807500081696], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;6&quot;, &quot;properties&quot;: {&quot;distance_meters&quo

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('IP Address:', socket.gethostbyname(socket.gethostname()))
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-1030-azure
# Datetime: 2025-10-04 13:43:54
# Python Version: 3.12.1
# IP Address: 127.0.0.1
# -----------------------------------
